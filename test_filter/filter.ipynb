# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
imagens = ['../dataset/test_real/plots/PMC2229834___5.jpg',
       '../dataset/test_real/plots/PMC2737149___10.jpg',
       '../dataset/test_real/plots/PMC2823789___g002.jpg',
       '../dataset/test_real/plots/PMC3111419___g004.jpg',
       '../dataset/test_real/plots/PMC3219711___03.jpg']

for img in imagens:
    # plot
    plt.figure(figsize=(5,5))
    plt.imshow(cv2.imread(img))
    plt.show()

# %%
for img in imagens:
    image = cv2.imread(img)
    edges = cv2.Canny(equalized_image, threshold1=50, threshold2=150)  # Ajuste os limiares conforme necessário
    # plot
    plt.figure(figsize=(5,5))
    plt.imshow(equalized_image)
    plt.show()

# %%
for img in imagens_synthetic:

    image = cv2.imread(img)

    sobel = cv.Sobel(img, -1, 1, 1)

    # processo de erosão e dilatação
    kernel = np.ones((5,5),np.uint8)
    dilation = cv2.dilate(image, kernel,iterations = 1)
    erosion = cv2.erode(dilation, kernel,iterations = 1)

    # plot
    plt.figure(figsize=(5,5))
    plt.imshow(erosion)
    plt.show()

# %%
for img in imagens:

    image = cv2.imread(img)

    # processo de erosão e dilatação
    kernel = np.ones((5,5),np.uint8)
    dilation = cv2.dilate(image, kernel,iterations = 1)
    erosion = cv2.erode(dilation, kernel,iterations = 1)

    b, g, r = cv2.split(erosion)
    red = cv2.equalizeHist(r)
    green = cv2.equalizeHist(g)
    blue = cv2.equalizeHist(b)
    img = cv2.merge((blue, green, red))

    img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

    # equalize the histogram of the Y channel
    img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

    # convert the YUV image back to RGB format
    img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)

    # plot
    plt.figure(figsize=(5,5))
    plt.imshow(img_output)
    plt.show()

# %%
for img in imagens_synthetic:

    image = cv2.imread(img)

    edges = cv2.Canny(image,100,200)

    # processo de erosão e dilatação
    # kernel = np.ones((5,5),np.uint8)
    # dilation = cv2.dilate(image, kernel,iterations = 1)
    # erosion = cv2.erode(dilation, kernel,iterations = 1)

    # plot
    plt.figure(figsize=(5,5))
    plt.imshow(edges)
    plt.show()
